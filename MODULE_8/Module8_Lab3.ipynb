# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-12 12:58:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   116MB/s    in 0.6s
#
# 2022-06-12 12:58:44 (116 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35208  cs/0107013v2  This is a tutorial on logic programming and Pr...    cs
# 22006   1310.6778v2  We consider learning the possible causal direc...  stat
# 13609   1401.0886v1  The concept of cognitive radio pioneered by Mi...    cs
# 39804  1705.02090v2  We introduce a novel neural network architectu...    cs
# 22123  1501.00604v1  Big data comes in various ways, types, shapes,...  stat
# ...             ...                                                ...   ...
# 28440  1706.06782v2  The need for large annotated image datasets fo...    cs
# 23900   1303.0964v1  Volumetric change in glioblastoma multiforme (...    cs
# 31436  1803.03893v2  Despite learning based methods showing promisi...    cs
# 32582   1404.4038v2  This work presents a sound probabilistic metho...    cs
# 14281  1605.07784v2  We consider the problem of Robust PCA in the f...    cs
#
#                                                    title  year  \
# 35208          The Logic Programming Paradigm and Prolog  2001
# 22006  Bayesian estimation of possible causal directi...  2013
# 13609  Spectrum Hole Prediction Based On Historical D...  2014
# 39804  GRASS: Generative Recursive Autoencoders for S...  2017
# 22123  A Taxonomy of Big Data for Optimal Predictive ...  2015
# ...                                                  ...   ...
# 28440  Object Detection Using Deep CNNs Trained on Sy...  2017
# 23900  GBM Volumetry using the 3D Slicer Medical Imag...  2013
# 31436  Unsupervised Learning of Monocular Depth Estim...  2018
# 32582  Discovering and Exploiting Entailment Relation...  2014
# 14281  Fast Algorithms for Robust PCA via Gradient De...  2016
#
#                                                 keywords
# 35208  [programming, appropriate, programming, langua...
# 22006  [direction, variables, confounding, variables,...
# 13609  [cognitive, pioneered, communication, especial...
# 39804  [introduce, architecture, synthesis, particula...
# 22123  [technology, economics, linguistics, bombarded...
# ...                                                  ...
# 28440  [annotated, convolutional, significant, impedi...
# 23900  [volumetric, glioblastoma, multiforme, treatme...
# 31436  [promising, estimation, approaches, supervised...
# 32582  [probabilistic, enforcing, adherence, probabil...
# 14281  [partially, corruptions, completion, statistic...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35208    [programming, appropriate, programming, langua...
# 22006    [direction, variables, confounding, variables,...
# 13609    [cognitive, pioneered, communication, especial...
# 39804    [introduce, architecture, synthesis, particula...
# 22123    [technology, economics, linguistics, bombarded...
#                                ...
# 21992    [statistical, dependency, dependency, variable...
# 23540    [deviation, accomplish, excellent, processing,...
# 32169    [maximization, algorithm, classification, part...
# 22258    [structured, estimation, dimensional, binaryca...
# 20700    [submission, discovery, dedicated, assessment,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8791 words.
# Out of those 4527 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ec8ab816-ff17-4f7d-939d-514f59ee8db4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec8ab816-ff17-4f7d-939d-514f59ee8db4")) {                    Plotly.newPlot(                        "ec8ab816-ff17-4f7d-939d-514f59ee8db4",                        [{"x":["appropriate","languages","programming","imperative","individual","relationship","structural","direction","effectiveness","estimating","variables","empirical","confounders","consistently","assumption","distorted","demonstrate","artificial","estimation","confounding","considered","nonlinear","obtaining","predicting","probability","occupancy","pioneered","measurement","optimizing","algorithm","temporally","cognitive","currently","historical","spectrally","assignment","prediction","communication","especially","increasing","opportunistically","management","interference","presented","organization","characterized","autoencoders","plausible","augmented","synthesis","generative","hierarchical","principles","arbitrary","hierarchy","structure","perceptual","relationships","framework","applications","supervision","adversarial","interpolation","fundamental","structures","introduce","architecture","autoencoder","unlabeled","particularly","hierarchies","associated","adjacency","recursive","significant","conditioned","bidirectional","meaningful","variations","effectively","classification","dimensional","complexities","particular","parallelization","penalization","hybridization","principle","regularization","imputation","outperforms","economics","ingredients","technology","different","linguistics","parsimony","efficiently","important","comparison","reduction","characterization","preprocessing","projection","universally","emphasize","compression","simplicity","predictive","technique","standardization","replication","kernelization","aggregation","performance","dimensionality","plurality","randomization","categories","selection","statistical","generated","performed","difficulty","constraints","mathematical","optionally","transformation","competitive","constrains","objective","minimizes","explanatory","introduced","describes","represents","compromise","representation","interaction","expression","interpretable","heuristic","computational","complicated","introduces","challenge","regression","shortcoming","expressions","reasonable","libraries","usability","supervised","distributed","unsupervised","efficiency","modularity","scientific","reproducibility","producing","compensate","averaging","consistent","distributions","adjusting","propagation","necessarily","graphical","previously","marginals","probabilities","algorithms","approximation","parameters","inference","approximate","inaccurate","perturbed","bivariate","logarithmic","seemingly","respectively","mechanisms","advantages","normalization","inferring","dirichlet","importance","marginalization","constructed","developed","including","theoretical","efficient","dispersion","distribution","highlight","connections","augmentation","restaurant"],"y":[82,99,114,4,111,74,67,65,211,69,115,152,0,35,72,12,584,133,217,1,129,47,45,86,168,9,1,34,53,802,23,54,61,15,4,20,217,68,118,106,2,47,14,173,26,25,26,28,51,48,129,85,36,98,29,330,20,75,556,421,57,119,16,86,151,323,242,29,50,90,11,112,5,24,243,21,26,58,66,118,497,205,15,242,4,1,3,45,81,1,244,5,5,60,780,23,0,158,332,124,97,30,20,54,1,11,39,29,65,241,2,1,1,21,915,58,1,4,65,153,153,182,116,46,145,56,3,58,116,6,146,21,5,112,78,53,8,350,101,44,27,49,292,25,69,136,124,6,49,29,11,11,212,107,151,172,2,31,2,29,7,31,89,120,7,63,14,56,98,5,78,569,114,244,228,104,7,9,1,21,5,105,50,72,29,20,16,85,4,76,204,239,163,415,3,201,30,48,23,1],"type":"bar"},{"x":["appropriate","languages","programming","imperative","individual","relationsh ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4527,), (4527, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8016666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Enhanced</span> <span style=''>high</span> <span style=''>dynamic</span> <span style=''>range</span> <span style=''>3D</span> <span style=''>shape</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>phase</span> <span style=''>shifting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style=''>Phase</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Measurement</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Profilometry</span> <span style=''>(PMP)</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>objects</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reflectivity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>across</span> <span style=''>the</span> <span style=''>surface</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Saturated</span> <span style=''>or</span> <span style=''>dark</span> <span style=''>pixels</span> <span style=''>in</span> <span style=''>the</span> <span style=''>deformed</span> <span style=''>fringe</span> <span style=''>patterns</span> <span style=''>captured</span> <span style=''>by</span> <span style=''>the</span> <span style=''>camera</span> <span style=''>will</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fluctuations</span> <span style=''>and</span> <span style=''>errors</span> <span style=''>Jiang</span> <span style=''>et</span> <span style=''>al</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>high</span> <span style=''>dynamic</span> <span style=''>range</span> <span style=''>real</span> <span style=''>time</span> <span style=''>3D</span> <span style=''>shape</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurement</span> <span style=''>method</span> <span style=''>without</span> <span style=''>changing</span> <span style=''>camera</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>exposures</span> <span style=''>Three</span> <span style=''>inverted</span> <span style=''>phase</span> <span style=''>shifted</span> <span style=''>fringe</span> <span style=''>patterns</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complement</span> <span style=''>three</span> <span style=''>regular</span> <span style=''>phase</span> <span style=''>shifted</span> <span style=''>fringe</span> <span style=''>patterns</span> <span style=''>for</span> <span style=''>phase</span> <span style='background-color:rgba(0, 255, 0, 0.6946564885496185);'>retrieval</span> <span style=''>when</span> <span style=''>any</span> <span style=''>of</span> <span style=''>the</span> <span style=''>regular</span> <span style=''>fringe</span> <span style=''>patterns</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>saturated</span> <span style=''>But</span> <span style=''>Jiangs</span> <span style=''>method</span> <span style=''>still</span> <span style=''>has</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>drawbacks</span> <span style=''>(1)</span> <span style=''>The</span> <span style=''>phases</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>saturated</span> <span style=''>pixels</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.438356164 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Subgroup</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identification</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interpretation</span> <span style=''>with</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Models</span> <span style=''>in</span> <span style=''>Health</span> <span style=''>Care</span> <span style=''>Claims</span> <span style=''>Data</span> <br/><br/><span style=''>Inpatient</span> <span style=''>care</span> <span style=''>is</span> <span style=''>a</span> <span style=''>large</span> <span style=''>share</span> <span style=''>of</span> <span style=''>total</span> <span style=''>health</span> <span style=''>care</span> <span style=''>spending</span> <span style=''>making</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>inpatient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilization</span> <span style=''>patterns</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>part</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>what</span> <span style=''>drives</span> <span style=''>health</span> <span style=''>care</span> <span style=''>spending</span> <span style=''>growth</span> <span style=''>Common</span> <span style=''>features</span> <span style=''>of</span> <span style=''>inpatient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilization</span> <span style=''>measures</span> <span style=''>include</span> <span style=''>zero</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inflation</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dispersion</span> <span style=''>and</span> <span style=''>skewness</span> <span style=''>all</span> <span style=''>of</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complicate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>modeling</span> <span style=''>Mixture</span> <span style=''>modeling</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accommodate</span> <span style=''>these</span> <span style=''>features</span> <span style=''>of</span> <span style=''>health</span> <span style=''>care</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilization</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>add</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>to</span> <span style=''>such</span> <span style=''>models</span> <span style=''>Our</span> <span style=''>fully</span> <span style=''>Bayesian</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>number</span> <span style=''>of</span> <span style=''>mixing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>When</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Average</span> <span style=''>Case</span> <span style=''>Active</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Costs</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>a</span> <span style=''>greedy</span> <span style=''>active</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>extends</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>to</span> <span style=''>a</span> <span style=''>more</span> <span style=''>general</span> <span style=''>setting</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3660245183887916);'>different</span> <span style=''>queries</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3660245183887916);'>different</span> <span style=''>costs</span> <span style=''>Moreover</span> <span style=''>queries</span> <span style=''>may</span> <span style=''>have</span> <span style=''>more</span> <span style=''>than</span> <span style=''>two</span> <span style=''>possible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>responses</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3104631217838765);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypotheses</span> <span style=''>may</span> <span style=''>be</span> <span style=''>non</span> <span style=''>uniform</span> <span style=''>Specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>include</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>label</span> <span style=''>costs</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.35999999999999993);'>multiclass</span> <span style=''>and</span> <span style=''>partial</span> <span style=''>label</span> <span style=''>queries</span> <span style=''>and</span> <span style=''>batch</span> <span style=''>mode</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>also</span> <span style=''>discuss</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>version</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>when</span> <span style=''>there</span> <span style=''>are</span> <span style=''>very</span> <span style=''>many</span> <span style=''>queries</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>Entropy</span> <span style=''>Search</span> <span style=''>for</span> <span style=''>Multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>PESMO</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style=''>Pareto</span> <span style=''>set</span> <span style=''>of</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>The</span> <span style=''>central</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>PESMO</span> <span style=''>is</span> <span style=''>to</span> <span style=''>choose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>points</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>entropy</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>the</span> <span style=''>Pareto</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Critically</span> <span style=''>the</span> <span style=''>PESMO</span> <span style=''>multi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>function</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sum</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>which</span> <span style=''>enables</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style=''>emphdecoupled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separately</span> <span style=''>and</span> <span style=''>perhaps</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>costs</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decoupling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>capability</span> <span style=''>also</span> <span style=''>makes</span> <span style=''>it</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12424565140220092)
# 	processing (0.09762158324458645)
# 	segmentation (0.06744763933262336)
# 	architecture (0.08590699325523607)
# 	knowledge (0.13205537806176784)
# 	experimental (0.14341498047568335)
# 	detection (0.116435924742634)
# 	convolutional (0.13525026624068157)
# 	different (0.27689030883919064)
# 	recognition (0.14235001774937878)
#
# Some Statistics words are:
# 	stochastic (0.13968734241048916)
# 	theoretical (0.15632879475542108)
# 	estimation (0.17599596570852244)
# 	statistical (0.156833081190116)
# 	variables (0.14573877962682805)
# 	algorithm (0.394856278366112)
# 	dimensional (0.18356026222894603)
# 	distribution (0.19263741805345436)
# 	inference (0.20474029248613212)
# 	regression (0.17851739788199697)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="19b83eb7-ad7e-4dbc-a189-a3b532a5ab9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19b83eb7-ad7e-4dbc-a189-a3b532a5ab9b")) {                    Plotly.newPlot(                        "19b83eb7-ad7e-4dbc-a189-a3b532a5ab9b",                        [{"x":["appropriate","languages","programming","imperative","individual","relationship","structural","direction","effectiveness","estimating","variables","empirical","confounders","consistently","assumption","distorted","demonstrate","artificial","estimation","confounding","considered","nonlinear","obtaining","predicting","probability","occupancy","pioneered","measurement","optimizing","algorithm","temporally","cognitive","currently","historical","spectrally","assignment","prediction","communication","especially","increasing","opportunistically","management","interference","presented","organization","characterized","autoencoders","plausible","augmented","synthesis","generative","hierarchical","principles","arbitrary","hierarchy","structure","perceptual","relationships","framework","applications","supervision","adversarial","interpolation","fundamental","structures","introduce","architecture","autoencoder","unlabeled","particularly","hierarchies","associated","adjacency","recursive","significant","conditioned","bidirectional","meaningful","variations","effectively","classification","dimensional","complexities","particular","parallelization","penalization","hybridization","principle","regularization","imputation","outperforms","economics","ingredients","technology","different","linguistics","parsimony","efficiently","important","comparison","reduction","characterization","preprocessing","projection","universally","emphasize","compression","simplicity","predictive","technique","standardization","replication","kernelization","aggregation","performance","dimensionality","plurality","randomization","categories","selection","statistical","generated","performed","difficulty","constraints","mathematical","optionally","transformation","competitive","constrains","objective","minimizes","explanatory","introduced","describes","represents","compromise","representation","interaction","expression","interpretable","heuristic","computational","complicated","introduces","challenge","regression","shortcoming","expressions","reasonable","libraries","usability","supervised","distributed","unsupervised","efficiency","modularity","scientific","reproducibility","producing","compensate","averaging","consistent","distributions","adjusting","propagation","necessarily","graphical","previously","marginals","probabilities","algorithms","approximation","parameters","inference","approximate","inaccurate","perturbed","bivariate","logarithmic","seemingly","respectively","mechanisms","advantages","normalization","inferring","dirichlet","importance","marginalization","constructed","developed","including","theoretical","efficient","dispersion","distribution","highlight","connections","augmentation","restaurant","processes","construct","geometric","properties","workflows","automatically","automated","complexity","statistically","optimization","available","typically","techniques","generalizability","exploiting","successful","successfully","systematically","replacement","independent","originally","reinforcement","dependent","baselines","experimental","counterparts","criterion","sufficient","significantly","byproduct","guaranteed","guarantees","stochastic","convergence","decisions","coefficient","therefore","connecting","semisupervised","boltzmann","constrained","intuitively","assigning","classified","posteriori","appearing","noticeable","inverting","experiments","according","extension","conditioning","empirically","specified","dete ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounders
# 	parsimony
# 	nonparametrics
# 	equalization
# 	covariances
# 	extrapolation
# 	assimilation
# 	counterfactual
# 	predetermined
# 	geostatistical
# 	eliciting
# 	decontamination
# 	subroutines
# 	methodologically
# 	elliptical
# 	pseudolikelihood
# 	parametrizations
# 	profitable
# 	semiparametric
# 	unconfounded
# Some words which never appear in Statistics papers:
# 	occupancy
# 	spectrally
# 	opportunistically
# 	commitment
# 	neuromorphic
# 	consecutively
# 	abstracting
# 	disruption
# 	corporate
# 	negotiate
# 	narratives
# 	coordinating
# 	attenuated
# 	competitions
# 	conceptnet
# 	affordances
# 	commonsense
# 	organizations
# 	differentiated
# 	sentiments

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.058384561274735e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7475
